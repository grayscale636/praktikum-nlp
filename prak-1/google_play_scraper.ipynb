# %% [markdown]
# 21110021

# %%
# !pip install google-play-scraper
# Out:
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.10/dist-packages (1.2.4)

# %%
from google_play_scraper import Sort, reviews, app
import pandas as pd
import numpy as np

# %%
result, continuation_token = reviews(
    'com.miHoYo.GenshinImpact',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=1000,
    filter_score_with=None
)

# %%
data = pd.DataFrame(np.array(result), columns=['review'])
data = data.join(pd.DataFrame(data.pop('review').tolist()))

# %%
data
# Out:
#                                  reviewId                  userName  \
# 0    7fb0c9f6-614e-4e43-883e-dd0246e99060       Novrealita Setiyana
# 1    da5c124f-4c4a-4b91-b1a2-cf790b6a87a9  070_Putri Azzahra Nurdin
# 2    2780771d-ee28-4df6-a142-dc925fcf9124                       Kai
# 3    c1374205-e58f-4e02-a209-d9dbfeaa7ca8                auah gelap
# 4    a4121d75-97f3-45d4-9d9d-5e64efff21f7               Adi Nugroho
# ..                                    ...                       ...
# 995  cd08069d-686f-4abc-b669-30ad638e52a3                    Azmi 1
# 996  f0bc8edd-ea06-496e-aa43-cd35c455521a        Siti khoerun Nissa
# 997  f44d00f6-fa99-4186-b32f-ae70ce62ca6d               Iqbal Rafif
# 998  c50d036a-ff3b-4a9e-b453-31cb7a89bae2                 bang dody
# 999  16ad2e2f-e612-4f21-a712-326a7f89024f               Ivan apriel
#
#                                              userImage  \
# 0    https://play-lh.googleusercontent.com/a-/ALV-U...
# 1    https://play-lh.googleusercontent.com/a-/ALV-U...
# 2    https://play-lh.googleusercontent.com/a-/ALV-U...
# 3    https://play-lh.googleusercontent.com/a-/ALV-U...
# 4    https://play-lh.googleusercontent.com/a/ACg8oc...
# ..                                                 ...
# 995  https://play-lh.googleusercontent.com/a-/ALV-U...
# 996  https://play-lh.googleusercontent.com/a/ACg8oc...
# 997  https://play-lh.googleusercontent.com/a/ACg8oc...
# 998  https://play-lh.googleusercontent.com/a-/ALV-U...
# 999  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                content  score  thumbsUpCount  \
# 0    Sejauh ini aku main aku suka banget sama model...      5             77
# 1    Bagus bgtt. Dari segi story, grafik sampe puzz...      5             25
# 2    Suka sama alur ceritanya, pengen ngasih bintan...      4             29
# 3    Semuanya sudah sempurna tapi Sangat disayangka...      3             12
# 4    Grafik bagus,story bagus,terutama archon quest...      5             33
# ..                                                 ...    ...            ...
# 995  Game nya bagus cuma event nya pelit ngasih had...      4              0
# 996  min ini gimna cara daftar nya? peraan dari tad...      3              0
# 997  Game nya bagus tapi login nya lama tak bisa ma...      3              0
# 998  Jir kecewa gua update udah 97% terus gagal bad...      1              0
# 999  Dari segi game play,grafik,co-op, karakter,sto...      5              0
#
#         reviewCreatedVersion                  at replyContent repliedAt  \
# 0    4.1.0_18054760_18121248 2023-09-27 00:17:58         None       NaT
# 1    4.0.0_16983586_17100363 2023-09-27 01:32:36         None       NaT
# 2    4.1.0_18054760_18121248 2023-09-27 14:22:12         None       NaT
# 3    4.0.0_16983586_17100363 2023-09-13 19:44:44         None       NaT
# 4    4.1.0_18054760_18121248 2023-09-26 23:53:28         None       NaT
# ..                       ...                 ...          ...       ...
# 995  4.0.0_16983586_17100363 2023-09-27 02:55:14         None       NaT
# 996  3.7.0_14806628_14807925 2023-06-25 23:43:27         None       NaT
# 997  3.8.0_15672274_15939604 2023-07-22 15:03:22         None       NaT
# 998  4.0.0_16983586_17100363 2023-08-16 13:23:17         None       NaT
# 999    2.4.0_5199000_5224067 2023-07-02 13:36:11         None       NaT
#
#                   appVersion
# 0    4.1.0_18054760_18121248
# 1    4.0.0_16983586_17100363
# 2    4.1.0_18054760_18121248
# 3    4.0.0_16983586_17100363
# 4    4.1.0_18054760_18121248
# ..                       ...
# 995  4.0.0_16983586_17100363
# 996  3.7.0_14806628_14807925
# 997  3.8.0_15672274_15939604
# 998  4.0.0_16983586_17100363
# 999    2.4.0_5199000_5224067
#
# [1000 rows x 11 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              1000 non-null   object
#  1   userName              1000 non-null   object
#  2   userImage             1000 non-null   object
#  3   content               1000 non-null   object
#  4   score                 1000 non-null   int64
#  5   thumbsUpCount         1000 non-null   int64
#  6   reviewCreatedVersion  988 non-null    object
#  7   at                    1000 non-null   datetime64[ns]
#  8   replyContent          28 non-null     object
#  9   repliedAt             28 non-null     datetime64[ns]
#  10  appVersion            988 non-null    object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 86.1+ KB

# %%
data.isna().sum()
# Out:
# reviewId                  0
# userName                  0
# userImage                 0
# content                   0
# score                     0
# thumbsUpCount             0
# reviewCreatedVersion     12
# at                        0
# replyContent            972
# repliedAt               972
# appVersion               12
# dtype: int64

# %%
dd = data['score'].value_counts().reset_index()
dd.columns = ['score', 'Counts']
dd = dd.sort_values(by='score')
dd
# Out:
#    score  Counts
# 2      1     117
# 4      2      43
# 3      3     110
# 1      4     170
# 0      5     560

# %%
df = pd.DataFrame(data[['userName', 'content', 'score']])

# %%
df
# Out:
#                      userName  \
# 0         Novrealita Setiyana
# 1    070_Putri Azzahra Nurdin
# 2                         Kai
# 3                  auah gelap
# 4                 Adi Nugroho
# ..                        ...
# 995                    Azmi 1
# 996        Siti khoerun Nissa
# 997               Iqbal Rafif
# 998                 bang dody
# 999               Ivan apriel
#
#                                                content  score
# 0    Sejauh ini aku main aku suka banget sama model...      5
# 1    Bagus bgtt. Dari segi story, grafik sampe puzz...      5
# 2    Suka sama alur ceritanya, pengen ngasih bintan...      4
# 3    Semuanya sudah sempurna tapi Sangat disayangka...      3
# 4    Grafik bagus,story bagus,terutama archon quest...      5
# ..                                                 ...    ...
# 995  Game nya bagus cuma event nya pelit ngasih had...      4
# 996  min ini gimna cara daftar nya? peraan dari tad...      3
# 997  Game nya bagus tapi login nya lama tak bisa ma...      3
# 998  Jir kecewa gua update udah 97% terus gagal bad...      1
# 999  Dari segi game play,grafik,co-op, karakter,sto...      5
#
# [1000 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.barplot(x='score', y='Counts', data=dd)
plt.title('Histogram Score Aplikasi')
plt.xlabel('score')
plt.ylabel('Count')
plt.show()
