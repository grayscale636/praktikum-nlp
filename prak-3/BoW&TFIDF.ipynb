# %%
import numpy as np
import pandas as pd

from luwiji.text_proc import illustration
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer, TfidfVectorizer

# %%
text = ['Ini adalah pensil',
        'Ini adalah pulpen saya dan ini pulpen dia',
        'Saya beli pensil ini',
        'Saya beli pulpen itu']
text
# Out:
# ['Ini adalah pensil',
#  'Ini adalah pulpen saya dan ini pulpen dia',
#  'Saya beli pensil ini',
#  'Saya beli pulpen itu']

# %% [markdown]
# ## Bag of Word

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('Bag of Words.png')

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
bow = CountVectorizer()
bow_matrix = bow.fit_transform(text)

# %%
bow_matrix
# Out:
# <4x9 sparse matrix of type '<class 'numpy.int64'>'
# 	with 17 stored elements in Compressed Sparse Row format>

# %%
pd.DataFrame(bow_matrix.toarray(), columns=bow.get_feature_names_out(), index=text)
# Out:
#                                            adalah  beli  dan  dia  ini  itu  \
# Ini adalah pensil                               1     0    0    0    1    0
# Ini adalah pulpen saya dan ini pulpen dia       1     0    1    1    2    0
# Saya beli pensil ini                            0     1    0    0    1    0
# Saya beli pulpen itu                            0     1    0    0    0    1
#
#                                            pensil  pulpen  saya
# Ini adalah pensil                               1       0     0
# Ini adalah pulpen saya dan ini pulpen dia       0       2     1
# Saya beli pensil ini                            1       0     1
# Saya beli pulpen itu                            0       1     1

# %% [markdown]
# ## Inverse Document Frequency (IDF)

# %%
illustration.inverse_df

# %% [markdown]
# ## Term Frequency - Inverse Document Frequency (TF-IDF)

# %%
tfidf = TfidfVectorizer()
tfidf_matrix = tfidf.fit_transform(text)

# %%
print(tfidf_matrix)
# Out:
#   (0, 6)	0.6136667440107333
#   (0, 0)	0.6136667440107333
#   (0, 4)	0.4968161174826459
#   (1, 3)	0.3741092304629382
#   (1, 2)	0.3741092304629382
#   (1, 8)	0.23878907574757022
#   (1, 7)	0.5899040287253255
#   (1, 0)	0.2949520143626628
#   (1, 4)	0.47757815149514043
#   (2, 1)	0.5495783541874525
#   (2, 8)	0.4449310425319985
#   (2, 6)	0.5495783541874525
#   (2, 4)	0.4449310425319985
#   (3, 5)	0.6142260844216118
#   (3, 1)	0.4842629000360712
#   (3, 8)	0.392052553254539
#   (3, 7)	0.4842629000360712

# %%
tfidf.get_feature_names_out()
# Out:
# array(['adalah', 'beli', 'dan', 'dia', 'ini', 'itu', 'pensil', 'pulpen',
#        'saya'], dtype=object)

# %%
pd.DataFrame(tfidf_matrix.toarray(), columns=tfidf.get_feature_names_out(), index=text)
# Out:
#                                              adalah      beli       dan  \
# Ini adalah pensil                          0.613667  0.000000  0.000000
# Ini adalah pulpen saya dan ini pulpen dia  0.294952  0.000000  0.374109
# Saya beli pensil ini                       0.000000  0.549578  0.000000
# Saya beli pulpen itu                       0.000000  0.484263  0.000000
#
#                                                 dia       ini       itu  \
# Ini adalah pensil                          0.000000  0.496816  0.000000
# Ini adalah pulpen saya dan ini pulpen dia  0.374109  0.477578  0.000000
# Saya beli pensil ini                       0.000000  0.444931  0.000000
# Saya beli pulpen itu                       0.000000  0.000000  0.614226
#
#                                              pensil    pulpen      saya
# Ini adalah pensil                          0.613667  0.000000  0.000000
# Ini adalah pulpen saya dan ini pulpen dia  0.000000  0.589904  0.238789
# Saya beli pensil ini                       0.549578  0.000000  0.444931
# Saya beli pulpen itu                       0.000000  0.484263  0.392053

# %% [markdown]
# kelemahan BoW dan TF-IDF:
# - urutan ngga ngaruh buat pembobotannya
