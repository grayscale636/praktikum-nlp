# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.4-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.4

# %%
from google_play_scraper import Sort, reviews, app
import pandas as pd
import numpy as np

# %%
result, continuation_token = reviews(
    'com.dts.freefireth',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=1000,
    filter_score_with=None
)

# %%
data = pd.DataFrame(np.array(result), columns=['review'])
data = data.join(pd.DataFrame(data.pop('review').tolist()))

# %%
data
# Out:
#                                  reviewId               userName  \
# 0    ca977f92-74a5-4788-93b9-f40d498d72e5  12. FIRMAN ARDIANSYAH
# 1    02aa325d-cdcf-4ea6-926b-02a4cc69be7c          aretha naveen
# 2    71e03d50-3c2d-47f8-b761-05c8ad9f091e            kayla tasya
# 3    0fb50aac-2cc5-45f5-9e42-473613f9e4b0              Alys Tria
# 4    7e7a2127-7514-4e29-9aa0-f1403a277ed4             Ginko Evin
# ..                                    ...                    ...
# 995  9a1a0cc4-3c15-42ea-a995-6cac7beb0cd6       As'ad Hutagalung
# 996  56e7053b-3605-4753-8ba1-e94f970c3c0a               ST Fandy
# 997  bc566c9d-27e7-4ab3-89fc-9f9b3f34318c         Arief Yulianto
# 998  b2d89461-9dae-4fde-8e3b-ed8212f88744         Stay Coll cees
# 999  5bfe73c6-b46a-4506-b595-fda5cc268572   Dhimas yolanda putra
#
#                                              userImage  \
# 0    https://play-lh.googleusercontent.com/a-/ALV-U...
# 1    https://play-lh.googleusercontent.com/a/ACg8oc...
# 2    https://play-lh.googleusercontent.com/a-/ALV-U...
# 3    https://play-lh.googleusercontent.com/a-/ALV-U...
# 4    https://play-lh.googleusercontent.com/a-/ALV-U...
# ..                                                 ...
# 995  https://play-lh.googleusercontent.com/a-/ALV-U...
# 996  https://play-lh.googleusercontent.com/a/ACg8oc...
# 997  https://play-lh.googleusercontent.com/a-/ALV-U...
# 998  https://play-lh.googleusercontent.com/a/ACg8oc...
# 999  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                content  score  thumbsUpCount  \
# 0    Uda bagus, cuman ada salah satu bug yang cukup...      4           3197
# 1    Terlalu banyak bug ketika permainan sedang ber...      2           2411
# 2    Gamenya bagus , tetapi knp banyak akun pro pla...      3           5358
# 3    Sangat gak puasss dalam bermain!!! Waktu main ...      1          14269
# 4    Moga cepat direspon, Yang tidak saya suka: - C...      1           4907
# ..                                                 ...    ...            ...
# 995  Peak yg dulu lebih menyenangkan tolong kembali...      5              1
# 996  Game nyabseru tapi masih ada bug bug gitu dan ...      4              0
# 997  Makin hari game banyak bug , contoh 1 . Masak ...      1           1127
# 998  Tolong nih game ntah kenapa setiap update jari...      1              1
# 999  FF broken. Mau nostalgia malah gak bisa main. ...      1              0
#
#     reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0                1.101.1 2023-09-23 09:36:39         None       NaT    1.101.1
# 1                1.101.1 2023-09-24 06:21:46         None       NaT    1.101.1
# 2                1.101.1 2023-09-21 07:51:05         None       NaT    1.101.1
# 3                1.100.1 2023-09-02 14:53:16         None       NaT    1.100.1
# 4                1.100.1 2023-09-17 11:41:03         None       NaT    1.100.1
# ..                   ...                 ...          ...       ...        ...
# 995              1.100.1 2023-08-12 00:55:16         None       NaT    1.100.1
# 996              1.100.1 2023-09-17 05:04:28         None       NaT    1.100.1
# 997               1.99.1 2023-06-13 04:02:50         None       NaT     1.99.1
# 998              1.100.1 2023-08-12 09:15:09         None       NaT    1.100.1
# 999              1.100.1 2023-08-12 07:55:42         None       NaT    1.100.1
#
# [1000 rows x 11 columns]
